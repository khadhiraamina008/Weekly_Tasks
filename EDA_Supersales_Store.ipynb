# %% [markdown]
# # EDA SUPERSALES STORE (9/9/2026)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os 
os.getcwd()
import pandas as pd
df = pd.read_csv(r"C:\Users\THASNEEM\OneDrive\Desktop\weeklytask\superstoredataset.csv")
print("Dataset Loaded Successfully")
# Out:
# Dataset Loaded Successfully

# %%
df # shows dataset
# Out:
#        Row ID        Order ID  Order Date  Ship Date       Ship Mode  \
# 0           1  US-2023-103800    1/3/2023   1/7/2023  Standard Class
# 1           2  US-2023-112326    1/4/2023   1/8/2023  Standard Class
# 2           3  US-2023-112326    1/4/2023   1/8/2023  Standard Class
# 3           4  US-2023-112326    1/4/2023   1/8/2023  Standard Class
# 4           5  US-2023-141817    1/5/2023  1/12/2023  Standard Class
# ...       ...             ...         ...        ...             ...
# 10189   10190  US-2026-143259  12/30/2026   1/3/2027  Standard Class
# 10190   10191  US-2026-115427  12/30/2026   1/3/2027  Standard Class
# 10191   10192  US-2026-156720  12/30/2026   1/3/2027  Standard Class
# 10192   10193  US-2026-143259  12/30/2026   1/3/2027  Standard Class
# 10193   10194  CA-2026-143500  12/30/2026   1/3/2027  Standard Class
#
#       Customer ID      Customer Name      Segment Country/Region  \
# 0        DP-13000      Darren Powers     Consumer  United States
# ...

# %%
# head() shows particular rows.. by default its 5 row
df.head(3)
# Out:
#    Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0       1  US-2023-103800   1/3/2023  1/7/2023  Standard Class    DP-13000
# 1       2  US-2023-112326   1/4/2023  1/8/2023  Standard Class    PO-19195
# 2       3  US-2023-112326   1/4/2023  1/8/2023  Standard Class    PO-19195
#
#    Customer Name      Segment Country/Region        City  ... Postal Code  \
# 0  Darren Powers     Consumer  United States     Houston  ...       77095
# 1  Phillina Ober  Home Office  United States  Naperville  ...       60540
# 2  Phillina Ober  Home Office  United States  Naperville  ...       60540
#
#     Region       Product ID         Category Sub-Category  \
# 0  Central  OFF-PA-10000174  Office Supplies        Paper
# 1  Central  OFF-BI-10004094  Office Supplies      Binders
# 2  Central  OFF-LA-10003223  Office Supplies       Labels
#
#                                         Product Name   Sales  Quantity  \
# ...

# %%
#tail shows last last 5 rows.. we can also show particular no, of rows
df.tail(2)
# Out:
#        Row ID        Order ID  Order Date Ship Date       Ship Mode  \
# 10192   10193  US-2026-143259  12/30/2026  1/3/2027  Standard Class
# 10193   10194  CA-2026-143500  12/30/2026  1/3/2027  Standard Class
#
#       Customer ID      Customer Name   Segment Country/Region           City  \
# 10192    PO-18865  Patrick O'Donnell  Consumer  United States  New York City
# 10193    HO-15230        Harry Olson  Consumer         Canada  Charlottetown
#
#        ... Postal Code Region       Product ID         Category Sub-Category  \
# 10192  ...       10009   East  TEC-PH-10004774       Technology       Phones
# 10193  ...         C0A   East  OFF-BI-10004040  Office Supplies      Binders
#
#                       Product Name   Sales  Quantity  Discount  Profit
# 10192    Gear Head AU3700S Headset  90.930         7       0.0  2.7279
# 10193  Wilson Jones Impact Binders   3.024         3       0.2 -0.6048
#
# [2 rows x 21 columns]

# %%
#random rows - no of rows can be changed ( by default its one)
df.sample(2)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 8542    8543  US-2026-152485    9/4/2026    9/8/2026  Standard Class
# 9508    9509  US-2026-118122  11/17/2026  11/24/2026  Standard Class
#
#      Customer ID Customer Name    Segment Country/Region     City  ...  \
# 8542    JD-15790    John Dryer   Consumer  United States  Coppell  ...
# 9508    GG-14650  Greg Guthrie  Corporate  United States  Seattle  ...
#
#      Postal Code   Region       Product ID         Category Sub-Category  \
# 8542       75019  Central  OFF-AR-10003759  Office Supplies          Art
# 9508       98103     West  OFF-BI-10002103  Office Supplies      Binders
#
#                                          Product Name   Sales  Quantity  \
# 8542                 Crayola Anti Dust Chalk, 12/Pack  10.192         7
# 9508  Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl  13.904         2
#
#       Discount  Profit
# 8542       0.2  3.1850
# 9508       0.2  4.5188
#
# [2 rows x 21 columns]

# %% [markdown]
# # DATASET DIMENSIONS

# %% [markdown]
# shape is for total no of rows and columns. size attribute returns total no of elements

# %%
print("Dataset Shape:",df.shape)
print("No. of rows:",df.shape[0])
print("No. of columns:",df.shape[1])
print("Total Elements:",df.size)
# Out:
# Dataset Shape: (10194, 21)
# No. of rows: 10194
# No. of columns: 21
# Total Elements: 214074

# %% [markdown]
# # COLUMN NAMES

# %% [markdown]
# Display all column names

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State/Province', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# # DATA TYPES

# %% [markdown]
# dtypes Display the datatypes of all columns

# %%
df.dtypes
# Out:
# Row ID              int64
# Order ID           object
# Order Date         object
# Ship Date          object
# Ship Mode          object
# Customer ID        object
# Customer Name      object
# Segment            object
# Country/Region     object
# City               object
# State/Province     object
# Postal Code        object
# Region             object
# Product ID         object
# Category           object
# Sub-Category       object
# Product Name       object
# Sales             float64
# Quantity            int64
# Discount          float64
# Profit            float64
# dtype: object

# %% [markdown]
# # DATASET INFORMATION

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          10194 non-null  int64
#  1   Order ID        10194 non-null  object
#  2   Order Date      10194 non-null  object
#  3   Ship Date       10194 non-null  object
#  4   Ship Mode       10194 non-null  object
#  5   Customer ID     10194 non-null  object
#  6   Customer Name   10194 non-null  object
#  7   Segment         10194 non-null  object
#  8   Country/Region  10194 non-null  object
#  9   City            10194 non-null  object
#  10  State/Province  10194 non-null  object
#  11  Postal Code     10194 non-null  object
#  12  Region          10194 non-null  object
#  13  Product ID      10194 non-null  object
#  14  Category        10194 non-null  object
#  15  Sub-Category    10194 non-null  object
#  16  Product Name    10194 non-null  object
# ...

# %% [markdown]
# # STATISTICAL SUMMARY

# %%
df.describe()
# Out:
#              Row ID         Sales      Quantity      Discount        Profit
# count  10194.000000  10194.000000  10194.000000  10194.000000  10194.000000
# mean    5097.500000    228.225854      3.791838      0.155385     28.673417
# std     2942.898656    619.906839      2.228317      0.206249    232.465115
# min        1.000000      0.444000      1.000000      0.000000  -6599.978000
# 25%     2549.250000     17.220000      2.000000      0.000000      1.760800
# 50%     5097.500000     53.910000      3.000000      0.200000      8.690000
# 75%     7645.750000    209.500000      5.000000      0.200000     29.297925
# max    10194.000000  22638.480000     14.000000      0.800000   8399.976000

# %% [markdown]
# # DATASET UNDERSTANDING
# # Numerical columns

# %%
numerical_columns=df.select_dtypes(include=np.number).columns #numerical columns
print("Numerical Columns:")
print(numerical_columns)
# Out:
# Numerical Columns:
# Index(['Row ID', 'Sales', 'Quantity', 'Discount', 'Profit'], dtype='object')

# %% [markdown]
# # Categorical Columns

# %% [markdown]
# Contains labels or groups

# %%
categorical_columns=df.select_dtypes(include='object').columns
print("Categorical Columns:")
print(categorical_columns)
# Out:
# Categorical Columns:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country/Region', 'City', 'State/Province',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name'],
#       dtype='object')

# %% [markdown]
# # Missing values

# %% [markdown]
# isnull() identifies missing values

# %% [markdown]
# sum() function counts the missing values in each column

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country/Region    0
# City              0
# State/Province    0
# Postal Code       0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# dtype: int64

# %% [markdown]
# # Removing null values

# %% [markdown]
# dropna() removes null values

# %%
print("Rows before removing null values:",df.shape[0])
df=df.dropna()
print("Rows after removing null values:",df.shape[0])
# Out:
# Rows before removing null values: 10194
# Rows after removing null values: 10194

# %%
df.isnull().sum() # verifying missing values
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country/Region    0
# City              0
# State/Province    0
# Postal Code       0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# dtype: int64

# %% [markdown]
# # Duplicate records

# %%
print("No. of duplicate rows:",df.duplicated().sum())
# Out:
# No. of duplicate rows: 0

# %%
df=df.drop_duplicates()
print("Dataset shape after removing duplicates:",df.shape)
# Out:
# Dataset shape after removing duplicates: (10194, 21)

# %% [markdown]
# # DATA CLEANING AND PREPROCESSING

# %% [markdown]
# # Converting date columns

# %%
df["Order Date"]=pd.to_datetime(df["Order Date"])
df["Ship Date"]=pd.to_datetime(df["Ship Date"])
df[["Order Date","Ship Date"]].dtypes
# Out:
# Order Date    datetime64[ns]
# Ship Date     datetime64[ns]
# dtype: object

# %%
text_columns=["Category","Sub-Category","Segment"]
for column in text_columns:
    df[column]=(
        df[column]
        .astype(str)
        .str.strip()
        .str.title()
    )

# %%
for column in text_columns:
    print("\n",column)
    print(df[column].unique())
# Out:
#  Category
# ['Office Supplies' 'Furniture' 'Technology']
#
#  Sub-Category
# ['Paper' 'Binders' 'Labels' 'Storage' 'Art' 'Chairs' 'Fasteners' 'Phones'
#  'Furnishings' 'Accessories' 'Bookcases' 'Envelopes' 'Appliances' 'Tables'
#  'Supplies' 'Machines' 'Copiers']
#
#  Segment
# ['Consumer' 'Home Office' 'Corporate']

# %% [markdown]
# # Data Check

# %%
print("Final Shape:",df.shape)
print("\nTotal Missing Values:",df.isnull().sum().sum())
print("Total Duplicate Rows:",df.duplicated().sum())
print("\nData Types:")
print(df.dtypes)
# Out:
# Final Shape: (10194, 21)
#
# Total Missing Values: 0
# Total Duplicate Rows: 0
#
# Data Types:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Country/Region            object
# City                      object
# State/Province            object
# Postal Code               object
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# dtype: object

# %% [markdown]
# # INITIAL EDA

# %% [markdown]
# # Summary Statistics

# %%
numerical_features=[
    "Sales",
    "Quantity",
    "Discount",
    "Profit"
]
df[numerical_features].describe()
# Out:
#               Sales      Quantity      Discount        Profit
# count  10194.000000  10194.000000  10194.000000  10194.000000
# mean     228.225854      3.791838      0.155385     28.673417
# std      619.906839      2.228317      0.206249    232.465115
# min        0.444000      1.000000      0.000000  -6599.978000
# 25%       17.220000      2.000000      0.000000      1.760800
# 50%       53.910000      3.000000      0.200000      8.690000
# 75%      209.500000      5.000000      0.200000     29.297925
# max    22638.480000     14.000000      0.800000   8399.976000

# %% [markdown]
# Initial Summary Statistics

# %%
summary=pd.DataFrame({
    "Mean":df[numerical_features].mean(),
    "Median":df[numerical_features].median(),
    "Minimum":df[numerical_features].min(),
    "Maximum":df[numerical_features].max(),
    "Standard Deviation":df[numerical_features].std()
})
summary
# Out:
#                 Mean  Median   Minimum    Maximum  Standard Deviation
# Sales     228.225854   53.91     0.444  22638.480          619.906839
# Quantity    3.791838    3.00     1.000     14.000            2.228317
# Discount    0.155385    0.20     0.000      0.800            0.206249
# Profit     28.673417    8.69 -6599.978   8399.976          232.465115

# %% [markdown]
# # SALES AND PROFIT ANALYSIS

# %% [markdown]
# # Category Wise Sales

# %%
category_sales=(
    df.groupby("Category")["Sales"]
    .sum()
    .sort_values(ascending=False)
)
category_sales
# Out:
# Category
# Technology         839893.2790
# Furniture          754747.7613
# Office Supplies    731893.3140
# Name: Sales, dtype: float64

# %% [markdown]
# # Category Wise Profit

# %%
category_profit=(
    df.groupby("Category")["Profit"]
    .sum()
    .sort_values(ascending=False)
)
category_profit
# Out:
# Category
# Technology         146543.3756
# Office Supplies    126023.4434
# Furniture           19729.9956
# Name: Profit, dtype: float64

# %% [markdown]
# # Sub-Category Wise Profit

# %%
sub_cat_profit=(
    df.groupby("Sub-Category")["Profit"]
    .sum()
    .sort_values(ascending=False)
)
sub_cat_profit
# Out:
# Sub-Category
# Copiers        56093.9365
# Phones         45050.8265
# Accessories    41936.6357
# Paper          34511.5070
# Binders        31426.1003
# Chairs         27223.5323
# Storage        21285.1115
# Appliances     18329.4844
# Furnishings    13891.7430
# Envelopes       6988.0247
# Art             6653.1962
# Labels          5572.7780
# Machines        3461.9769
# Fasteners       2428.6358
# Supplies       -1171.3945
# Bookcases      -3632.0736
# Tables        -17753.2061
# Name: Profit, dtype: float64

# %% [markdown]
# # Region Wise Profit

# %%
region_profit=(
    df.groupby("Region")["Profit"]
    .sum()
    .sort_values(ascending=False)
)
region_profit
# Out:
# Region
# West       110798.8170
# East        94883.2603
# South       46749.4303
# Central     39865.3070
# Name: Profit, dtype: float64

# %%
region_profit=(
    df.groupby("Region")["Sales"]
    .sum()
    .sort_values(ascending=False)
)
region_profit
# Out:
# Region
# West       739813.6085
# East       691828.1680
# Central    503170.6728
# South      391721.9050
# Name: Sales, dtype: float64

# %% [markdown]
# # VISUALISATION USING SEABORN (11/09/2026)

# %% [markdown]
# # Category-wise total sales

# %%
plt.figure(figsize=(4,5))
sns.barplot(
    data=df,
    x="Category",
    y="Sales",
    estimator="sum"
)
plt.title("Category-wise Total Sales")
plt.xlabel("Category")
plt.ylabel("Total Sales")
plt.show()

# %% [markdown]
# # Category-wise Profit

# %%
plt.figure(figsize=(4,5))
sns.barplot(
    data=df,
    x="Category",
    y="Profit",
    estimator="sum"
)
plt.title("Category-wise Total Sales")
plt.xlabel("Category")
plt.ylabel("Profit")
plt.show()

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %% [markdown]
# # Sales Distribution

# %%
plt.figure(figsize=(4,4))
sns.boxplot(
    data=df,
    y="Sales"
)
plt.title("Sales Distribution")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# # Profit Distribution

# %%
plt.figure(figsize=(4,4))
sns.boxplot(
    data=df,
    y="Profit"
)
plt.title("Profit Distribution")
plt.ylabel("Profit")
plt.show()

# %% [markdown]
# # BIVARIATE ANALYSIS

# %% [markdown]
# # Profit Distribution by Category

# %%
plt.figure(figsize=(4,4))
sns.boxplot(
    data=df,
    x="Category",
    y="Profit"
)
plt.title("Profit Distribution by Category")
plt.xlabel("Category")
plt.ylabel("Profit")
plt.show()

# %% [markdown]
# # Discount vs Profit

# %%
plt.figure(figsize=(7,6))
sns.scatterplot(
    data=df,
    x="Discount",
    y="Profit"
)
plt.title("Discount vs Profit")
plt.xlabel("Discount")
plt.ylabel("Profit")
plt.show()

# %% [markdown]
# # CALCULATIONG PROFIT MARGIN

# %% [markdown]
# FORMULA:-
# Profit Margin =(Profit/Sales)*100

# %%
df["Profit Margin"] = df["Profit"]/df["Sales"]*100
df[["Sales","Profit","Profit Margin"]].head()
# Out:
#      Sales   Profit  Profit Margin
# 0   16.448   5.5512          33.75
# 1    3.540  -5.4870        -155.00
# 2   11.784   4.2717          36.25
# 3  272.736 -64.7748         -23.75
# 4   19.536   4.8840          25.00

# %% [markdown]
# # Discount vs Profit Margin

# %%
plt.figure(figsize=(7,6))
sns.scatterplot(
    data=df,
    x="Discount",
    y="Profit Margin"
)
plt.title("Discount vs Profit Margin")
plt.xlabel("Discount")
plt.ylabel("Profit Margin")
plt.show()

# %% [markdown]
# # CORRELATION ANALYSIS

# %% [markdown]
# # Correlation
#
# -1 --------> Strong Negetive Relationship
#
# 0 ---------> No Relationship
#
# +1 --------> Strong Positive Relationship

# %%
numerical_df=df.select_dtypes(include=np.number)
correlation_matrix=numerical_df.corr()
correlation_matrix
# Out:
#                  Row ID     Sales  Quantity  Discount    Profit  Profit Margin
# Row ID         1.000000 -0.008958  0.000502 -0.001474  0.003022       0.001198
# Sales         -0.008958  1.000000  0.198457 -0.027756  0.481460       0.002707
# Quantity       0.000502  0.198457  1.000000  0.007475  0.066145      -0.003830
# Discount      -0.001474 -0.027756  0.007475  1.000000 -0.218882      -0.864821
# Profit         0.003022  0.481460  0.066145 -0.218882  1.000000       0.223224
# Profit Margin  0.001198  0.002707 -0.003830 -0.864821  0.223224       1.000000

# %% [markdown]
# # Correlation Heatmap

# %%
plt.figure(figsize=(7,6))
sns.heatmap(
    correlation_matrix,
    annot=True,
    fmt=".2f",
    cmap="coolwarm"
)
plt.title("Correlation Heatmap of Numerical Attributes")
plt.show()

# %% [markdown]
# # Business Insights
#
# ##### 1. Which category has the highest sales?
# Technology
# ##### 2. Which category has the lowest sales?
# Office Supplies
# ##### 3. Which regions contribute most to sales?
# West
# ##### 4. Which category generates the highest profit?
# Technology
# ##### 5. Which sub-categories have the low or negative profit?
# Tables
# ##### 6. Which regions are most profitable?
# West
# ##### 7. Does profit decrease as discount increases?
# Yes
# ##### 8. Which discount levels have poor profitability?
# 0.8
# ##### 9. Which high-discount transactions generate negative profit?
# 0.7
# ##### 10. Which variables have strong positive correlation?
# Sales and Profit
# ##### 11. Which variables have negative correlation?
# Discount and Profit
# ##### 12. Is Discount negatively related to Profit
# Yes, Discount is negetively related to profit

# %% [markdown]
#  # REPORT

# %% [markdown]
# ##### The Sample Superstore Sales Dataset contains 9,994 rows and 21 columns, covering retail transactions from 2014 to 2017.
#
# ##### The data was cleaned, and date columns were converted into datetime format.
#
# ##### Exploratory Data Analysis (EDA) was performed using bar charts, boxplots, scatter plots, and correlation analysis to understand sales, profit, and discount patterns.
#
# ##### Technology recorded the highest sales of approximately 839,857 Dollars and the highest profit of 146,543 Dollars while Furniture generated relatively low profit of $19,729 despite its substantial sales.
#
# ##### The West region was the leading contributor to sales, with approximately $739,813.
#
# ##### Correlation analysis indicated a strong negative relationship between Discount and Profit Margin, with a reported correlation of −0.86, suggesting that higher discounts are generally associated with lower profitability.
#
# ##### The analysis highlights the importance of managing discounts, improving Furniture's profitability, and focusing on  profitable product categories and regions.
#
# ##### Businesses should use data-driven decisions, monitor discount policies, and conduct further analysis before implementing major pricing changes.
