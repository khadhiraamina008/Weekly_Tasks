# %%
# import libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv(r"C:\Users\THASNEEM\OneDrive\Desktop\weeklytask\healthcare_dataset.csv")

# %%
# 1. Display first 5 rows
print("First Records")
df.head()
# Out:
# First Records
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
# 2. Display last 5 rows
print("Last Records")
df.tail()
# Out:
# Last Records
#                     Name  Age  Gender Blood Type Medical Condition  \
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission           Doctor                      Hospital  \
# 55495        2020-08-16    Joshua Jarvis                Jones-Thompson
# 55496        2020-01-23  Taylor Sullivan                  Tucker-Moyer
# 55497        2020-07-13   Joe Jacobs DVM  and Mahoney Johnson Vasquez,
# 55498        2019-05-25   Kimberly Curry      Jackson Todd and Castro,
# 55499        2024-04-02    Dennis Warren                Henry Sons and
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# ...

# %%
# 3. Dispplay random rows
print("Random Records")
df.sample(4)
# Out:
# Random Records
#                     Name  Age  Gender Blood Type Medical Condition  \
# 1995         LEroy priCE   42  Female         O-         Arthritis
# 1837   mRs. JilliaN sOsa   29    Male         O-          Diabetes
# 33939      pATTY sAnTana   65  Female        AB+            Cancer
# 47357        JaY RObBinS   52  Female         O-      Hypertension
#
#       Date of Admission           Doctor                  Hospital  \
# 1995         2022-04-18       David Sims  Ortega, Taylor Berry and
# 1837         2024-01-22     Jenna Larson              Thomas-Adams
# 33939        2022-04-22       Raymond Wu       Bell Pham, Cruz and
# 47357        2022-03-03  Kimberly Burton                 PLC Huang
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# 1995    UnitedHealthcare    44407.343247          192         Urgent
# 1837               Aetna    47906.009014          379      Emergency
# ...

# %%
# 4. Display dimensions of the dataset
print("Dimensions")
df.shape
# Out:
# Dimensions
# (55500, 15)

# %%
# 5. Display column names
print("Column Names")
df.columns
# Out:
# Column Names
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %%
# 6. Display datatypes of the attributes
print("Datatypes")
df.dtypes
# Out:
# Datatypes
# Name                   object
# Age                     int64
# Gender                 object
# Blood Type             object
# Medical Condition      object
# Date of Admission      object
# Doctor                 object
# Hospital               object
# Insurance Provider     object
# Billing Amount        float64
# Room Number             int64
# Admission Type         object
# Discharge Date         object
# Medication             object
# Test Results           object
# dtype: object

# %%
# 7. Display dataset information
print("Dataset Information")
df.info()
# Out:
# Dataset Information
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55500 entries, 0 to 55499
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                55500 non-null  object
#  1   Age                 55500 non-null  int64
#  2   Gender              55500 non-null  object
#  3   Blood Type          55500 non-null  object
#  4   Medical Condition   55500 non-null  object
#  5   Date of Admission   55500 non-null  object
#  6   Doctor              55500 non-null  object
#  7   Hospital            55500 non-null  object
#  8   Insurance Provider  55500 non-null  object
#  9   Billing Amount      55500 non-null  float64
#  10  Room Number         55500 non-null  int64
#  11  Admission Type      55500 non-null  object
#  12  Discharge Date      55500 non-null  object
#  13  Medication          55500 non-null  object
#  14  Test Results        55500 non-null  object
# ...

# %%
# 8. Display statistical summary 
print("Statistical Summary")
df.describe
# Out:
# Statistical Summary
# <bound method NDFrame.describe of                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# ...

# %%
print("Missing values")
df.isnull()
# Out:
# Missing values
#         Name    Age  Gender  Blood Type  Medical Condition  Date of Admission  \
# 0      False  False   False       False              False              False
# 1      False  False   False       False              False              False
# 2      False  False   False       False              False              False
# 3      False  False   False       False              False              False
# 4      False  False   False       False              False              False
# ...      ...    ...     ...         ...                ...                ...
# 55495  False  False   False       False              False              False
# 55496  False  False   False       False              False              False
# 55497  False  False   False       False              False              False
# 55498  False  False   False       False              False              False
# 55499  False  False   False       False              False              False
#
# ...

# %%
print("Total number of missing values")
df.isnull().sum()
# Out:
# Total number of missing values
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
print("Removing missing values")
df.dropna()
# Out:
# Removing missing values
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# ...

# %%
print("Duplicate values")
df.duplicated()
# Out:
# Duplicate values
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 55495    False
# 55496    False
# 55497    False
# 55498    False
# 55499    False
# Length: 55500, dtype: bool

# %%
print("Removing duplicates")
df.drop_duplicates()
# Out:
# Removing duplicates
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# ...

# %%
print("Date Conversion")
df["Date of Admission"]=pd.to_datetime(df["Date of Admission"])
df[["Date of Admission"]].dtypes
# Out:
# Date Conversion
# Date of Admission    datetime64[ns]
# dtype: object

# %%
print("Numeric conversion")
df["Billing Amount"]=pd.to_numeric(df["Billing Amount"])
df[["Billing Amount"]].dtypes
# Out:
# Numeric conversion
# Billing Amount    float64
# dtype: object

# %%
print("Unique Values")
df["Doctor"].unique()
# Out:
# Unique Values
# array(['Matthew Smith', 'Samantha Davies', 'Tiffany Mitchell', ...,
#        'Deborah Sutton', 'Mary Bartlett', 'Alec May'],
#       shape=(40341,), dtype=object)

# %%
print("Frequency")
df["Insurance Provider"].value_counts()
# Out:
# Frequency
# Insurance Provider
# Cigna               11249
# Medicare            11154
# UnitedHealthcare    11125
# Blue Cross          11059
# Aetna               10913
# Name: count, dtype: int64

# %%
print("Grouping")
df["Test Results"].groupby
# Out:
# Grouping
# <bound method Series.groupby of 0              Normal
# 1        Inconclusive
# 2              Normal
# 3            Abnormal
# 4            Abnormal
#              ...
# 55495        Abnormal
# 55496          Normal
# 55497        Abnormal
# 55498        Abnormal
# 55499        Abnormal
# Name: Test Results, Length: 55500, dtype: object>

# %%
print("Aggregation")
print(df.groupby('Medical Condition')['Billing Amount'].agg(['mean','median','min','max','std','count']))
# Out:
# Aggregation
#                            mean        median          min           max  \
# Medical Condition
# Arthritis          25497.327056  25581.763549 -1129.997176  52170.036854
# Asthma             25635.249359  25661.872824 -1520.420555  52181.837792
# Cancer             25161.792707  24910.980640 -2008.492140  52373.032374
# Diabetes           25638.405577  25621.077269 -1316.618581  52211.852966
# Hypertension       25497.095761  25275.670593 -1660.009373  52764.276736
# Obesity            25805.971259  26129.997134 -1310.272895  52024.726443
#
#                             std  count
# Medical Condition
# Arthritis          14276.529904   9308
# Asthma             14241.677464   9185
# Cancer             14200.271700   9227
# Diabetes           14159.524315   9304
# Hypertension       14305.400942   9245
# Obesity            14079.526507   9231

# %%
print("Grouping")
df.groupby('Medical Condition')['Billing Amount'].mean() 
df.groupby('Gender')['Age'].mean()
# Out:
# Grouping
# Gender
# Female    51.578735
# Male      51.500252
# Name: Age, dtype: float64

# %%
print("Median")
df.groupby("Medical Condition")["Age"].median()
# Out:
# Median
# Medical Condition
# Arthritis       52.0
# Asthma          52.0
# Cancer          52.0
# Diabetes        52.0
# Hypertension    52.0
# Obesity         51.0
# Name: Age, dtype: float64

# %%
df.sort_values("Billing Amount",ascending=False)
# Out:
#                    Name  Age  Gender Blood Type Medical Condition  \
# 36349     tOdd CARrILlO   51  Female         A+      Hypertension
# 51313       kARen klInE   74  Female        AB+            Cancer
# 34613       kARen klInE   79  Female        AB+            Cancer
# 5735     DAVId SanDOvaL   22    Male        AB-      Hypertension
# 7088   kathRYN GoNzales   18  Female         O+          Diabetes
# ...                 ...  ...     ...        ...               ...
# 29484      tErRy WILSOn   39    Male         O-          Diabetes
# 44040    JOsEPH robBins   71    Male         O-      Hypertension
# 42621         joHn hahN   80    Male         O-            Asthma
# 48659       EMMA savAGE   57    Male        AB+      Hypertension
# 47589        james lUnA   64  Female        AB-            Cancer
#
#       Date of Admission             Doctor                     Hospital  \
# 36349        2023-09-08   Kathleen Griffin                Griffin Group
# ...

# %%
print("Maximum value")
df["Age"].max()
# Out:
# Maximum value
# 89

# %%
print("Minimum value")
df["Age"].min()
# Out:
# Minimum value
# 13

# %%
print("Standard Deviation")
df["Billing Amount"].std()
# Out:
# Standard Deviation
# 14211.45443086446

# %%
print("Quantile")
df["Billing Amount"].quantile(0.25)
# Out:
# Quantile
# np.float64(13241.224652365136)

# %%
print("Text Standardization")
df["Name"].str.strip().str.title()
# Out:
# Text Standardization
# 0            Bobby Jackson
# 1             Leslie Terry
# 2              Danny Smith
# 3             Andrew Watts
# 4            Adrienne Bell
#                ...
# 55495    Elizabeth Jackson
# 55496           Kyle Perez
# 55497         Heather Wang
# 55498       Jennifer Jones
# 55499         James Garcia
# Name: Name, Length: 55500, dtype: object

# %%
print("-:Conditional Filtering:-")
df[(df['Age'] > 20) & (df['Age'] < 50) ]
# Out:
# -:Conditional Filtering:-
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# 5          EMILY JOHNSOn   36    Male         A+            Asthma
# 6         edwArD EDWaRDs   21  Female        AB-          Diabetes
# ...                  ...  ...     ...        ...               ...
# 55488      briTtNeY York   43  Female         B-           Obesity
# 55491      lInDA grIFfin   47  Female         O+           Obesity
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# ...

# %%
df[(df["Billing Amount"] > 20000) & (df["Billing Amount"] < 50000) ]
# Out:
#                      Name  Age  Gender Blood Type Medical Condition  \
# 1            LesLie TErRy   62    Male         A+           Obesity
# 2             DaNnY sMitH   76  Female         A-           Obesity
# 3            andrEw waTtS   28  Female         O+          Diabetes
# 5           EMILY JOHNSOn   36    Male         A+            Asthma
# 7      CHrisTInA MARtinez   20  Female         A+            Cancer
# ...                   ...  ...     ...        ...               ...
# 55489      ANdrEw AGUIlaR   69    Male         O-         Arthritis
# 55494       JEssIcA WHiTe   67    Male         O+         Arthritis
# 55496          KYle pEREz   61  Female        AB-           Obesity
# 55497        HEATher WaNG   38  Female         B+      Hypertension
# 55498      JENniFER JOneS   43    Male         O-         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 1            2019-08-20   Samantha Davies                       Kim Inc
# ...

# %%
df[df['Test Results']=='Abnormal']
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 3             andrEw waTtS   28  Female         O+          Diabetes
# 4            adrIENNE bEll   43  Female        AB+            Cancer
# 8          JASmINe aGuIlaR   82    Male        AB+            Asthma
# 12           connOR HANsEn   75  Female         A+          Diabetes
# 17     mRS. jamiE cAMPBELl   38    Male        AB-           Obesity
# ...                    ...  ...     ...        ...               ...
# 55493         gLoRIA BOWen   57  Female         B-         Arthritis
# 55495    eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55497         HEATher WaNG   38  Female         B+      Hypertension
# 55498       JENniFER JOneS   43    Male         O-         Arthritis
# 55499         jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# ...

# %%
df[(df['Billing Amount'] > 50000) & (df['Age'] > 60)]
# Out:
#                          Name  Age  Gender Blood Type Medical Condition  \
# 8             JASmINe aGuIlaR   82    Male        AB+            Asthma
# 165             traCEY grEenE   85    Male         O-            Cancer
# 1763            jENNiFEr wEST   83    Male         A+            Asthma
# 1848             tAyLor JOnES   66  Female         A-         Arthritis
# 1886   JEFFReY livIngSTON DDS   84  Female        AB-         Arthritis
# ...                       ...  ...     ...        ...               ...
# 51313             kARen klInE   74  Female        AB+            Cancer
# 52048          GaBRIel hARris   64  Female         A-            Asthma
# 53467         MichEllE DUncaN   63    Male         A+      Hypertension
# 54478            aDaM wATkins   67    Male         O+      Hypertension
# 54819         stePhaNie smith   79    Male         O-           Obesity
#
#       Date of Admission             Doctor           Hospital  \
# ...

# %%
df[df['Blood Type'] == 'B-']
# Out:
#                      Name  Age  Gender Blood Type Medical Condition  \
# 0           Bobby JacksOn   30    Male         B-            Cancer
# 30        ThOMAS MartInEZ   34    Male         B-            Asthma
# 37     CasSAndrA Robinson   26  Female         B-      Hypertension
# 39       PAmela fErNanDeZ   57  Female         B-           Obesity
# 40        chRiSTOPHer LEe   74  Female         B-      Hypertension
# ...                   ...  ...     ...        ...               ...
# 55479    mIcHAeL SanTiAgo   58  Female         B-            Cancer
# 55480        LAurEn mills   33  Female         B-          Diabetes
# 55488       briTtNeY York   43  Female         B-           Obesity
# 55490    STepHAniE oliVer   82    Male         B-            Cancer
# 55493        gLoRIA BOWen   57  Female         B-         Arthritis
#
#       Date of Admission               Doctor               Hospital  \
# 0            2024-01-31        Matthew Smith        Sons and Miller
# ...

# %%
condition_summary=(
    df.groupby("Medical Condition")["Billing Amount"]
    .mean()
    .reset_index()
)
condition_summary
# Out:
#   Medical Condition  Billing Amount
# 0         Arthritis    25497.327056
# 1            Asthma    25635.249359
# 2            Cancer    25161.792707
# 3          Diabetes    25638.405577
# 4      Hypertension    25497.095761
# 5           Obesity    25805.971259

# %%
df["Length of Stay"]=(
    pd.to_datetime(df["Discharge Date"])-
    pd.to_datetime(df["Date of Admission"])
).dt.days
df[["Date of Admission", "Discharge Date","Length of Stay"]].head()
# Out:
#   Date of Admission Discharge Date  Length of Stay
# 0        2024-01-31     2024-02-02               2
# 1        2019-08-20     2019-08-26               6
# 2        2022-09-22     2022-10-07              15
# 3        2020-11-18     2020-12-18              30
# 4        2022-09-19     2022-10-09              20

# %%
df[["Age", "Billing Amount", "Room Number", "Length of Stay"]].corr()
# Out:
#                      Age  Billing Amount  Room Number  Length of Stay
# Age             1.000000       -0.003832    -0.000720        0.008220
# Billing Amount -0.003832        1.000000    -0.002943       -0.005602
# Room Number    -0.000720       -0.002943     1.000000       -0.005526
# Length of Stay  0.008220       -0.005602    -0.005526        1.000000

# %%
df['Admission Year']=pd.to_datetime(
    df['Date of Admission']
    ).dt.year

df[['Date of Admission','Admission Year']].head()
# Out:
#   Date of Admission  Admission Year
# 0        2024-01-31            2024
# 1        2019-08-20            2019
# 2        2022-09-22            2022
# 3        2020-11-18            2020
# 4        2022-09-19            2022

# %%
df.groupby('Admission Year')['Billing Amount'].mean()
# Out:
# Admission Year
# 2019    25700.463671
# 2020    25392.254250
# 2021    25629.483239
# 2022    25513.509808
# 2023    25573.848469
# 2024    25380.295013
# Name: Billing Amount, dtype: float64

# %%
df["Admission Month"]=pd.to_datetime(
    df["Date of Admission"]
).dt.year
df[["Date of Admission","Admission Month"]].head()
# Out:
#   Date of Admission  Admission Month
# 0        2024-01-31             2024
# 1        2019-08-20             2019
# 2        2022-09-22             2022
# 3        2020-11-18             2020
# 4        2022-09-19             2022

# %%
monthly_admissions=(
    df.groupby("Admission Month")["Name"]
    .count()
    .reset_index()
)

monthly_admissions
# Out:
#    Admission Month   Name
# 0             2019   7387
# 1             2020  11285
# 2             2021  10931
# 3             2022  11017
# 4             2023  11026
# 5             2024   3854

# %%
plt.figure(figsize=(9,5))
sns.lineplot(
    data=monthly_admissions,
    x="Admission Month",
    y="Name",
    marker="o"
)
plt.title("Monthly number of admissions")
plt.xlabel("Admission Month")
plt.ylabel("Number of admissions")
plt.show()

# %%
plt.figure(figsize=(4,5))
sns.barplot(
    data=df,
    x="Billing Amount",
    y="Admission Month",
    estimator="sum"
)
plt.xlabel("Billing Amount")
plt.ylabel("Admission Month")
plt.show()
